-- %% [markdown]
-- Server wide performance counters

-- %%
SELECT start_time, end_time, avg_cpu_percent, avg_data_io_percent, avg_log_write_percent, dtu_limit, cpu_limit
FROM sys.resource_stats WITH (NOLOCK) 
ORDER BY end_time desc;
-- Out:
-- (282 rows affected)
-- Total execution time: 00:00:00.047
-- ...
